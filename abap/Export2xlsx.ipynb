# %% [markdown]
# # Export created sales order to MS Excel

# %% [markdown]
# ## ABAP-part
# ABAP program `ZUCC_ANALYTICS_SDGEN_EXPORT` exports the sales orders of the selected year to a TSV file.
# It accesses the CDS-View `c_salesdocumentitemdex` and extracts a fixed list of fields (matching the Python code below).
# You might want to save the TSV file in the `data/` folder here for the sake of simplicity.

# %% [markdown]
# ## Convert downloaded TSV-file to Excel

# %%
import pandas as pd

# %% [markdown]
# Column list has to match the above mentioned ABAP program.

# %%
columns = [
    "salesdocument", "salesdocumentitem"
    , "salesorganization", "distributionchannel", "division"
    , "material", "soldtoparty", "salesdocumentdate", "requesteddeliverydate"
    , "orderquantity", "orderquantityunit", "itemgrossweight", "itemweightunit"
    , "netamount", "transactioncurrency", "taxamount", "costamount", "subtotal1amount"
    , "plant"
]

# %%
# ask for filename
import tkinter
from tkinter import filedialog
root = tkinter.Tk()
root.wm_withdraw() # this completely hides the root window
filename = filedialog.askopenfilename(title='Select .tsv file')
root.destroy()

# %%
df = pd.read_csv(filename, sep='\t', header=None, names=columns)
df
# Out:
#      salesdocument  salesdocumentitem salesorganization distributionchannel  \
# 0               48                 10              DN00                  WH
# 1               48                 20              DN00                  WH
# 2               48                 40              DN00                  WH
# 3               48                 50              DN00                  WH
# 4               48                 60              DN00                  WH
# ..             ...                ...               ...                 ...
# 535            119                 40              UE00                  WH
# 536            119                 50              UE00                  WH
# 537            119                 70              UE00                  WH
# 538            119                 90              UE00                  WH
# 539            119                100              UE00                  WH
#
#     division                                  material  soldtoparty  \
# 0         AS  FAID1000                                       141000
# 1         AS  CAGE1000                                       141000
# 2         AS  PUMP1000                                       141000
# 3         AS  RKIT1000                                       141000
# 4         BI  ORWN1000                                       141000
# ..       ...                                       ...          ...
# 535       AS  KPAD1000                                       126000
# 536       AS  CAGE1000                                       126000
# 537       AS  RKIT1000                                       126000
# 538       BI  PRTR3000                                       126000
# 539       AS  RHMT1000                                       126000
#
#      salesdocumentdate  requesteddeliverydate  orderquantity  \
# 0             20150101               20150101           10.0
# 1             20150101               20150101           11.0
# 2             20150101               20150101           13.0
# 3             20150101               20150101            9.0
# 4             20150101               20150101            9.0
# ..                 ...                    ...            ...
# 535           20150112               20150202           10.0
# 536           20150112               20150202           16.0
# 537           20150112               20150202           12.0
# 538           20150112               20150202           12.0
# 539           20150112               20150202           12.0
#
#     orderquantityunit  itemgrossweight itemweightunit  netamount  \
# 0                 EA             120.0            OZ      412.00
# 1                 EA              88.0            OZ      203.94
# 2                 EA             130.0            OZ      374.92
# 3                 EA             108.0            OZ      296.64
# 4                 EA           86040.0            G     23175.00
# ..                ...              ...            ...        ...
# 535               EA             160.0            OZ      727.50
# 536               EA             128.0            OZ      279.36
# 537               EA             144.0            OZ      372.48
# 538               EA           87720.0            G     37248.00
# 539               EA             120.0            OZ      582.00
#
#     transactioncurrency  taxamount  costamount  subtotal1amount plant
# 0                 EUR        78.28       200.0            400.0  HH00
# 1                 EUR        38.75        99.0            198.0  HH00
# 2                 EUR        71.23       182.0            364.0  HH00
# 3                 EUR        56.36       144.0            288.0  HH00
# 4                 EUR      4403.25     11250.0          22500.0  HH00
# ..                  ...        ...         ...              ...   ...
# 535               USD         0.00       375.0            750.0  MI00
# 536               USD         0.00       144.0            288.0  MI00
# 537               USD         0.00       192.0            384.0  MI00
# 538               USD         0.00     18000.0          38400.0  MI00
# 539               USD         0.00       300.0            600.0  MI00
#
# [540 rows x 19 columns]

# %%
filename.replace('.tsv', '.xlsx')
df.to_excel('../data/2015analytics.xlsx', index=False)
